# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
network = pd.read_csv(r"C:\Users\siles\Desktop\DSKTOP\JOB\Tuva\FBI\SNA_Dummy_Data_Example_v1.csv")

G = nx.Graph()

edges = ()
a =()
for i in range(len(network["T"])):
    a = tuple(network["T"][[i]]) + tuple(network["F"][[i]]) 
    edges = edges + (a ,)

G.add_edges_from(edges)
G.number_of_nodes()
G.number_of_edges()

#nx.draw_networkx(G, pos, **options)
nx.draw_networkx(G)

nx.draw(G)
plt.show()
# Out:
# c:\Users\siles\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
